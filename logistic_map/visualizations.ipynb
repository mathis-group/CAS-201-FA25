# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
xs = [1,2,3,4,5]
ys = [x**2 + 10 for x in xs]
plt.scatter(xs,ys)

# %%
import logistic
import random

r = 3.67
time_steps = 20
x0 = random.random()

xs = logistic.run_logistic(r,x0,time_steps)
ts = range(time_steps+2)

plt.plot(ts,xs)
