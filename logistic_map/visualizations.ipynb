# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = [1,2,3,4,5]
ys = [x**2 + 10 for x in xs]

# %%
plt.scatter(xs, ys, marker = "o")

# %%
from logistic import logistic, run_logistic

# %%
r = 2.0
x0 = 0.0001
time_steps = 20
xs = np.array([x0])
xs_plus = run_logistic(r, x0, time_steps)
time_steps_array = np.array([i for i in range(time_steps + 2)])
plt.plot(time_steps_array, xs_plus)
